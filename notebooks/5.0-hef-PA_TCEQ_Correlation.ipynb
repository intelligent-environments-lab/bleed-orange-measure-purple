# %% [markdown]
# # Relationship Between Purple Air and TCEQ Measurements
# In this notebook, we explore the relationship between the measurements made on campus to the surrounding TCEQ measurement sites to see if there is any relationship.

# %%
import pandas as pd
import sys
sys.path.append('../')
import src.data.purpleair_raw_cleaner as pa_cleaner

# %% [markdown]
# ## Importing, Cleaning, and Combining Raw PA Data

# %%
pa_cleaner.main(path="../data/raw/purpleair/",
        save_location="./pa_data",)
# Out:
# Importing csvs
# Processing data
# PA_II_DA7A
# PA_II_0E49
# PA_II_D8BE
# PA_II_D8B6
# PA_II_D71C
# PA_II_0ED1
# PA_II_0DA8
# PA_II_E6D8
# PA_II_0D9C
# PA_II_0DA2
# PA_II_0E47
# PA_II_806B
# PA_II_6A1A
# PA_II_D727
# PA_II_D44F

# %%
data = pd.read_parquet("./pa_data")

# %%
data
# Out:
#                                        entry_id  PM1.0_CF1_ug/m3  \
# sensor_name created_at
# PA_II_DA7A  2019-12-31 18:00:00-06:00  108620.0             0.72
#             2019-12-31 18:02:00-06:00  108621.0             0.74
#             2019-12-31 18:04:00-06:00  108622.0             0.91
#             2019-12-31 18:06:00-06:00  108623.0             0.76
#             2019-12-31 18:08:00-06:00  108624.0             0.72
# ...                                         ...              ...
# PA_II_D44F  2020-06-01 18:50:00-05:00  211634.0             6.30
#             2020-06-01 18:52:00-05:00  211635.0             6.46
#             2020-06-01 18:54:00-05:00  211636.0             5.51
#             2020-06-01 18:56:00-05:00  211637.0             6.13
#             2020-06-01 18:58:00-05:00  211638.0             5.61
#
#                                        PM2.5_CF1_ug/m3  PM10.0_CF1_ug/m3  \
# sensor_name created_at
# ...
